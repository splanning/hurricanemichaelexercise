# %%
import pandas as pd
import geopandas as gpd #used for transforming geolocation data
import matplotlib.pyplot as plt

from datetime import datetime  #to convert data to datetime that does not fall within the pandas.to_datetime function timeframe
from shapely.geometry import Point  #transform latitude/longitude to geo-coordinate data
from geopandas.tools import geocode #get the latitude/longitude for a given address
from geopandas.tools import reverse_geocode  #get the address for a location using latitude/longitude

# %matplotlib inline

# %%
#load hurricane data
mike_df = pd.read_csv("datasets/hurricaneMichael.csv")
mike_df.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  10/06/2018 17:00  18.0  86.6    30  1006
# 1             1A  10/06/2018 20:00  18.3  86.6    30  1004
# 2              2  10/06/2018 23:00  18.8  86.6    30  1004
# 3             2A  10/07/2018 02:00  18.4  87.1    35  1004
# 4              3  10/07/2018 05:00  18.6  86.9    35  1004
#
#                  Movement                        Type      Name  \
# 0   NW at 6 MPH (325 deg)  Potential Tropical Cyclone  Fourteen
# 1    N at 6 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 2    N at 7 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 3   NW at 5 MPH (320 deg)  Potential Tropical Cyclone  Fourteen
# 4  NNW at 3 MPH (340 deg)         Tropical Depression  FOURTEEN
#
#            Received Forecaster
# 0  10/06/2018 16:50      Beven
# 1  10/06/2018 19:32      Avila
# 2  10/06/2018 22:38      Avila
# 3  10/07/2018 01:38       Berg
# 4  10/07/2018 04:53       Berg

# %%
#check data counts
mike_df.count()
# Out:
# AdvisoryNumber    45
# Date              45
# Lat               45
# Long              45
# Wind              45
# Pres              45
# Movement          45
# Type              45
# Name              45
# Received          45
# Forecaster        45
# dtype: int64

# %%
#data type of each column
mike_df.dtypes
# Out:
# AdvisoryNumber     object
# Date               object
# Lat               float64
# Long              float64
# Wind                int64
# Pres                int64
# Movement           object
# Type               object
# Name               object
# Received           object
# Forecaster         object
# dtype: object

# %%
#Convert positive longitude values to negative longitude values
mike_df['Long'] = 0 - mike_df['Long']

# %%
#confirm new data
mike_df.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  10/06/2018 17:00  18.0 -86.6    30  1006
# 1             1A  10/06/2018 20:00  18.3 -86.6    30  1004
# 2              2  10/06/2018 23:00  18.8 -86.6    30  1004
# 3             2A  10/07/2018 02:00  18.4 -87.1    35  1004
# 4              3  10/07/2018 05:00  18.6 -86.9    35  1004
#
#                  Movement                        Type      Name  \
# 0   NW at 6 MPH (325 deg)  Potential Tropical Cyclone  Fourteen
# 1    N at 6 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 2    N at 7 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 3   NW at 5 MPH (320 deg)  Potential Tropical Cyclone  Fourteen
# 4  NNW at 3 MPH (340 deg)         Tropical Depression  FOURTEEN
#
#            Received Forecaster
# 0  10/06/2018 16:50      Beven
# 1  10/06/2018 19:32      Avila
# 2  10/06/2018 22:38      Avila
# 3  10/07/2018 01:38       Berg
# 4  10/07/2018 04:53       Berg

# %%
#make a new column to hold the longitude & latitude as a list
mike_df['coordinates'] = list(mike_df[['Long', 'Lat']].values)

# %%
#see new coordinates column
mike_df.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  10/06/2018 17:00  18.0 -86.6    30  1006
# 1             1A  10/06/2018 20:00  18.3 -86.6    30  1004
# 2              2  10/06/2018 23:00  18.8 -86.6    30  1004
# 3             2A  10/07/2018 02:00  18.4 -87.1    35  1004
# 4              3  10/07/2018 05:00  18.6 -86.9    35  1004
#
#                  Movement                        Type      Name  \
# 0   NW at 6 MPH (325 deg)  Potential Tropical Cyclone  Fourteen
# 1    N at 6 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 2    N at 7 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 3   NW at 5 MPH (320 deg)  Potential Tropical Cyclone  Fourteen
# 4  NNW at 3 MPH (340 deg)         Tropical Depression  FOURTEEN
#
#            Received Forecaster    coordinates
# 0  10/06/2018 16:50      Beven  [-86.6, 18.0]
# 1  10/06/2018 19:32      Avila  [-86.6, 18.3]
# 2  10/06/2018 22:38      Avila  [-86.6, 18.8]
# ...

# %%
#list values in coordinates column is classified as object type
mike_df['coordinates'].dtypes
# Out:
# dtype('O')

# %%
#convert the coordinates to a geolocation type
mike_df['coordinates'] = mike_df['coordinates'].apply(Point)

# %%
#coordinates column now has POINT next to each coordinate pair value
mike_df.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  10/06/2018 17:00  18.0 -86.6    30  1006
# 1             1A  10/06/2018 20:00  18.3 -86.6    30  1004
# 2              2  10/06/2018 23:00  18.8 -86.6    30  1004
# 3             2A  10/07/2018 02:00  18.4 -87.1    35  1004
# 4              3  10/07/2018 05:00  18.6 -86.9    35  1004
#
#                  Movement                        Type      Name  \
# 0   NW at 6 MPH (325 deg)  Potential Tropical Cyclone  Fourteen
# 1    N at 6 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 2    N at 7 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 3   NW at 5 MPH (320 deg)  Potential Tropical Cyclone  Fourteen
# 4  NNW at 3 MPH (340 deg)         Tropical Depression  FOURTEEN
#
#            Received Forecaster                      coordinates
# 0  10/06/2018 16:50      Beven    POINT (-86.59999999999999 18)
# 1  10/06/2018 19:32      Avila  POINT (-86.59999999999999 18.3)
# ...

# %%
#see current data type
mike_df.dtypes
# Out:
# AdvisoryNumber     object
# Date               object
# Lat               float64
# Long              float64
# Wind                int64
# Pres                int64
# Movement           object
# Type               object
# Name               object
# Received           object
# Forecaster         object
# coordinates        object
# dtype: object

# %%
#coordinates column with geolocation data is just a regular pandas Series type
type(mike_df['coordinates'])
# Out:
# pandas.core.series.Series

# %%
#create a geolocation dataframe type using the coordinates column as the geolocation data
geo_mike = gpd.GeoDataFrame(mike_df, geometry='coordinates')

# %%
#geo-dataframe looks the same as regular dataframe
geo_mike.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  10/06/2018 17:00  18.0 -86.6    30  1006
# 1             1A  10/06/2018 20:00  18.3 -86.6    30  1004
# 2              2  10/06/2018 23:00  18.8 -86.6    30  1004
# 3             2A  10/07/2018 02:00  18.4 -87.1    35  1004
# 4              3  10/07/2018 05:00  18.6 -86.9    35  1004
#
#                  Movement                        Type      Name  \
# 0   NW at 6 MPH (325 deg)  Potential Tropical Cyclone  Fourteen
# 1    N at 6 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 2    N at 7 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 3   NW at 5 MPH (320 deg)  Potential Tropical Cyclone  Fourteen
# 4  NNW at 3 MPH (340 deg)         Tropical Depression  FOURTEEN
#
#            Received Forecaster                 coordinates
# 0  10/06/2018 16:50      Beven  POINT (-86.60000 18.00000)
# 1  10/06/2018 19:32      Avila  POINT (-86.60000 18.30000)
# ...

# %%
#verify coordinates column is geolocation data type
type(geo_mike['coordinates'])
# Out:
# geopandas.geoseries.GeoSeries

# %%
#look at data types
geo_mike.dtypes
# Out:
# AdvisoryNumber      object
# Date                object
# Lat                float64
# Long               float64
# Wind                 int64
# Pres                 int64
# Movement            object
# Type                object
# Name                object
# Received            object
# Forecaster          object
# coordinates       geometry
# dtype: object

# %%
#import file that contains a US map shape polygons
#will use to plot the coordinates of hurricane path
filepath = "datasets/US_states(5m).json"

#data contains polygon shape coordinates for different map body types (states)
map_df = gpd.read_file(filepath)
map_df
# Out:
#          GEO_ID STATE                  NAME LSAD  CENSUSAREA  \
# 0   0400000US01    01               Alabama        50645.326
# 1   0400000US02    02                Alaska       570640.950
# 2   0400000US04    04               Arizona       113594.084
# 3   0400000US05    05              Arkansas        52035.477
# 4   0400000US06    06            California       155779.220
# 5   0400000US08    08              Colorado       103641.888
# 6   0400000US09    09           Connecticut         4842.355
# 7   0400000US10    10              Delaware         1948.543
# 8   0400000US11    11  District of Columbia           61.048
# 9   0400000US12    12               Florida        53624.759
# 10  0400000US13    13               Georgia        57513.485
# 11  0400000US15    15                Hawaii         6422.628
# 12  0400000US16    16                 Idaho        82643.117
# 13  0400000US17    17              Illinois        55518.930
# ...

# %%
#Select just the contiguous 48 US States
map48 = map_df.loc[map_df['NAME'].isin(['Alaska', 'Hawaii', 'Puerto Rico']) == False]
map48
# Out:
#          GEO_ID STATE                  NAME LSAD  CENSUSAREA  \
# 0   0400000US01    01               Alabama        50645.326
# 2   0400000US04    04               Arizona       113594.084
# 3   0400000US05    05              Arkansas        52035.477
# 4   0400000US06    06            California       155779.220
# 5   0400000US08    08              Colorado       103641.888
# 6   0400000US09    09           Connecticut         4842.355
# 7   0400000US10    10              Delaware         1948.543
# 8   0400000US11    11  District of Columbia           61.048
# 9   0400000US12    12               Florida        53624.759
# 10  0400000US13    13               Georgia        57513.485
# 12  0400000US16    16                 Idaho        82643.117
# 13  0400000US17    17              Illinois        55518.930
# 14  0400000US18    18               Indiana        35826.109
# 15  0400000US19    19                  Iowa        55857.130
# ...

# %%
#map graph
map48.plot()
# Out:
# <AxesSubplot:>

# %%
#plot the coordinates (no map)
geo_mike.plot()
# Out:
# <AxesSubplot:>

# %%
#plot coordinates on top of map graph

#this is to set the size of the borders
fig, ax = plt.subplots(1, figsize=(10,7))

#this is the map
basemap = map48.plot(ax=ax)

#plot coordinates on top of map graph
geo_mike.plot(ax=basemap, color='orange', marker="2", markersize=20)

#take off axis numbers
ax.axis('off')

#put title on map
ax.set_title("Path of Hurricane Michael, October 2018", fontsize=25, fontweight=3)
# Out:
# Text(0.5, 1.0, 'Path of Hurricane Michael, October 2018')
